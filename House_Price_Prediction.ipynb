# %%
import pandas as pd
import warnings
import statsmodels.api as sm
import os
import numpy as np
import seaborn as sns
from sklearn.feature_selection import mutual_info_regression
from matplotlib import pylab as plt
from IPython.core.interactiveshell import InteractiveShell

# %%
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=Warning)
InteractiveShell.ast_node_interactivity = 'all'

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

def set_seed(seed=42):
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
set_seed()

sns.set_style('whitegrid')
sns.set_context('paper', font_scale=1.5)
plt.style.use('fivethirtyeight')
pd.set_option("display.width", 100)
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 30)

plt.rcParams["figure.autolayout"] = True
plt.rcParams["axes.grid"] = True
plt.rcParams["grid.alpha"] = 0.5
plt.rcParams["grid.linestyle"] = '--'
plt.rcParams["font.family"] = "monospace"
plt.rcParams["axes.facecolor"] = "white"
plt.rcParams['axes.edgecolor'] = 'black'
plt.rcParams['figure.frameon'] = True
plt.rcParams['axes.spines.left'] = True
plt.rcParams['axes.spines.bottom'] = True
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.linewidth'] = 1.5

print("setup-complete!")
# Out:
# setup-complete!

# %%
data = pd.read_csv("/content/House-Price-Prediction-clean.csv")
del data["Id"]

X = data.drop(columns=["SalePrice"])
y = data["SalePrice"]

# %%
data.head().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_36234_row0_col0, #T_36234_row2_col0, #T_36234_row4_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# ...

# %%
data.tail().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_91f0e_row0_col0 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 31 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   LotArea        1460 non-null   int64
#  2   OverallQual    1460 non-null   int64
#  3   OverallCond    1460 non-null   int64
#  4   YearBuilt      1460 non-null   int64
#  5   YearRemodAdd   1460 non-null   int64
#  6   BsmtFinSF1     1460 non-null   int64
#  7   BsmtUnfSF      1460 non-null   int64
#  8   TotalBsmtSF    1460 non-null   int64
#  9   1stFlrSF       1460 non-null   int64
#  10  2ndFlrSF       1460 non-null   int64
#  11  GrLivArea      1460 non-null   int64
#  12  BsmtFullBath   1460 non-null   int64
#  13  FullBath       1460 non-null   int64
#  14  HalfBath       1460 non-null   int64
#  15  BedroomAbvGr   1460 non-null   int64
#  16  KitchenAbvGr   1460 non-null   int64
#  17  TotRmsAbvGrd   1460 non-null   int64
# ...

# %%
missing_value_count = data.isnull().sum()

missing_value_count.to_frame().T.style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_76647_row0_col0, #T_76647_row0_col1, #T_76647_row0_col2, #T_76647_row0_col3, #T_76647_row0_col4, #T_76647_row0_col5, #T_76647_row0_col6, #T_76647_row0_col7, #T_76647_row0_col8, #T_76647_row0_col9, #T_76647_row0_col10, #T_76647_row0_col11, #T_76647_row0_col12, #T_76647_row0_col13, #T_76647_row0_col14, #T_76647_row0_col15, #T_76647_row0_col16, #T_76647_row0_col17, #T_76647_row0_col18, #T_76647_row0_col19, #T_76647_row0_col20, #T_76647_row0_col21, #T_76647_row0_col22, #T_76647_row0_col23, #T_76647_row0_col24, #T_76647_row0_col25, #T_76647_row0_col26, #T_76647_row0_col27, #T_76647_row0_col28, #T_76647_row0_col29, #T_76647_row0_col30 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_76647" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76647_level0_col0" class="col_heading level0 col0" >MSSubClass</th>
# ...

# %%
(data.describe(include=[np.number],
               percentiles=[.25, .5, .75])
               .astype("int64")
               .style.background_gradient(cmap="Blues"))
# Out:
# <style type="text/css">
# #T_5a08d_row0_col0, #T_5a08d_row0_col2, #T_5a08d_row0_col3, #T_5a08d_row0_col12, #T_5a08d_row0_col13, #T_5a08d_row0_col14, #T_5a08d_row0_col15, #T_5a08d_row0_col16, #T_5a08d_row0_col17, #T_5a08d_row0_col18, #T_5a08d_row0_col19, #T_5a08d_row0_col20, #T_5a08d_row0_col21, #T_5a08d_row0_col22, #T_5a08d_row0_col23, #T_5a08d_row0_col24, #T_5a08d_row0_col25, #T_5a08d_row0_col26, #T_5a08d_row0_col28, #T_5a08d_row1_col29, #T_5a08d_row3_col29, #T_5a08d_row4_col29, #T_5a08d_row5_col29, #T_5a08d_row6_col5, #T_5a08d_row6_col29, #T_5a08d_row7_col1, #T_5a08d_row7_col4, #T_5a08d_row7_col5, #T_5a08d_row7_col6, #T_5a08d_row7_col7, #T_5a08d_row7_col8, #T_5a08d_row7_col9, #T_5a08d_row7_col10, #T_5a08d_row7_col11, #T_5a08d_row7_col27, #T_5a08d_row7_col29, #T_5a08d_row7_col30 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# ...

# %%
(data.corr()["SalePrice"]
     .sort_values(ascending=False)
     .to_frame().T
     .style.background_gradient(cmap="Blues"))
# Out:
# <style type="text/css">
# #T_558fc_row0_col0, #T_558fc_row0_col1, #T_558fc_row0_col2, #T_558fc_row0_col3, #T_558fc_row0_col4, #T_558fc_row0_col5, #T_558fc_row0_col6, #T_558fc_row0_col7, #T_558fc_row0_col8, #T_558fc_row0_col9, #T_558fc_row0_col10, #T_558fc_row0_col11, #T_558fc_row0_col12, #T_558fc_row0_col13, #T_558fc_row0_col14, #T_558fc_row0_col15, #T_558fc_row0_col16, #T_558fc_row0_col17, #T_558fc_row0_col18, #T_558fc_row0_col19, #T_558fc_row0_col20, #T_558fc_row0_col21, #T_558fc_row0_col22, #T_558fc_row0_col23, #T_558fc_row0_col24, #T_558fc_row0_col25, #T_558fc_row0_col26, #T_558fc_row0_col27, #T_558fc_row0_col28, #T_558fc_row0_col29, #T_558fc_row0_col30 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_558fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_558fc_level0_col0" class="col_heading level0 col0" >SalePrice</th>
# ...

# %%
X_mutual = data.drop(columns=["SalePrice"]).reset_index().copy()
y_mutual = data["SalePrice"]

del X_mutual["index"]

discrete_features = X_mutual.dtypes == int

# %%
def make_mi_score(X_mutual, y_mutual, discrete_features):
    mi_scores = mutual_info_regression(X_mutual, y_mutual, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X_mutual.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_score(X_mutual, y_mutual, discrete_features)
mi_scores.to_frame().T
# Out:
#            OverallQual  GarageArea  GrLivArea  YearBuilt  TotalBsmtSF   LotArea  GarageCars  \
# MI Scores     0.568624    0.496543   0.432761    0.41003     0.397917  0.392961    0.360005
#
#            MSSubClass  1stFlrSF  YearRemodAdd  FullBath  TotRmsAbvGrd  OpenPorchSF  2ndFlrSF  \
# MI Scores    0.288794  0.279445      0.276771  0.264053      0.223458     0.191916  0.170135
#
#            Fireplaces  BsmtFinSF1  BsmtUnfSF  OverallCond  WoodDeckSF  HalfBath  BedroomAbvGr  \
# MI Scores    0.161717    0.157985   0.118683     0.116145    0.100286  0.097709      0.066708
#
#            EnclosedPorch  KitchenAbvGr  ScreenPorch  BsmtFullBath    YrSold  3SsnPorch  \
# MI Scores       0.026947      0.021463     0.021415      0.017385  0.011667   0.000855
#
#                PoolArea  MiscVal  MoSold
# MI Scores  2.220446e-16      0.0     0.0

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.figure(figsize=(20, 10))
    plt.barh(width, scores, color="blue")
    plt.yticks(width, ticks)
    plt.title("Mutual Information Scores",
              weight="bold",
              fontsize=25, pad=25)

plot_mi_scores(mi_scores)

# %%
X = sm.add_constant(X)
est = sm.OLS(y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.809
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     201.6
# Date:                Wed, 24 Jan 2024   Prob (F-statistic):               0.00
# Time:                        14:48:57   Log-Likelihood:                -17336.
# No. Observations:                1460   AIC:                         3.473e+04
# Df Residuals:                    1429   BIC:                         3.490e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
net = LinearRegression()

# %%
net.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_data = net.predict(X_test)
train_data = net.predict(X_train)

# %%
test_r2_score = r2_score(y_test, test_data)
print(f'Test R2_score: {test_r2_score:.2f}')

test_mse = mean_absolute_error(y_test, test_data)
print(f'Test MSE : {test_mse:.2f}')

test_RMSE = mean_squared_error(y_test, test_data)
print(f'Test RMSE : {test_RMSE:.2f}')
# Out:
# Test R2_score: 0.82
# Test MSE : 22523.56
# Test RMSE : 1260986886.41

# %%
test = pd.DataFrame({'Predicted Price':test_data, 'Actual Price':y_test})
fig = plt.figure(figsize=(24, 16))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test, linewidth=1)
plt.ylim(0, 800000)
plt.legend(['Actual Price','Predicted Price'])
plt.title('Actual & Predicted Price (Test Data)', weight="bold", fontsize=25, pad=30)
plt.annotate("A lot of predictive Data goes far beyond the Actual,\nbut yes, this is natural in the field of Machine Learning,\nbecause, it's very hard to construct a working model that\nworks 100% with no weaknesses.",
             xy=(200, 600000), xytext=(200, 600000))
plt.xticks(weight="bold")
plt.yticks(weight="bold")
plt.show();

# %% [markdown]
# ---

# %%
train_r2_score = r2_score(y_train, train_data)
print(f'Train R2_score: {train_r2_score:.2f}')

train_mse = mean_absolute_error(y_train, train_data)
print(f'Train MSE : {train_mse:.2f}')

train_RMSE = mean_squared_error(y_train, train_data)
print(f'Train RMSE : {train_RMSE:.2f}')
# Out:
# Train R2_score: 0.80
# Train MSE : 21353.49
# Train RMSE : 1207860804.52

# %%
train = pd.DataFrame({'Predicted Price':train_data, 'Actual Price':y_train})
fig= plt.figure(figsize=(24, 16))
train = train.reset_index()
train = train.drop(['index'],axis=1)
plt.plot(train, linewidth=1)
plt.ylim(0, 800000)
plt.legend(['Actual Price','Predicted Price'])
plt.title('Actual & Predicted Price (Train Data)', weight="bold", fontsize=25, pad=30)
plt.xticks(weight="bold")
plt.yticks(weight="bold")
plt.show();

# %% [markdown]
# ---
